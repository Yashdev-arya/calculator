# %%
def addition(a,b):
  return (a+b)
def division(a,b):
  if(b==0):
    print("enter valid second number for division")
  else:
    return a/b
def multiply(a,b):
  return a*b
def subtraction(a,b):
  return a-b
while True :
  print("calculator is on what operation you want to perform yashdev")
  print("chooses the operation you want to perform ")
  print("for addition choose = +")
  print("for subtraction choose = -")
  print("for division choose = / ")
  print("for multiplication choose = x")
  print("for exit choose= exit")
  choice = (input("enter your choice="))
  if (choice.lower() != "exit") :
     print("enter two numbers to perfrom operation :")
     try:
         number_1 = float(input("enter  your first number:"))
         number_2=float(input("enter your second number:"))
     except valueerror :
         print("enter valid float numbers to perform the operation")


     if choice == "+":
       print(addition(number_1,number_2))
     elif choice == "-":
       print(subtraction(number_1,number_2))
     elif choice == "/":
       print(division(number_1,number_2))
     elif choice == "x":
       print(multiply(number_1,number_2))
     else :
      print("enter  your choce from given options ")
  else:
    print("calculator is  off")
    break
# Out:
# calculator is on what operation you want to perform yashdev
# chooses the operation you want to perform
# for addition choose = +
# for subtraction choose = -
# for division choose = /
# for multiplication choose = x
# for exit choose= exit
# enter your choice=+
# enter two numbers to perfrom operation :
# enter  your first number:1
# enter your second number:3
# 4.0
# calculator is on what operation you want to perform yashdev
# chooses the operation you want to perform
# for addition choose = +
# for subtraction choose = -
# for division choose = /
# for multiplication choose = x
# for exit choose= exit
# enter your choice=exit
# calculator is  off
